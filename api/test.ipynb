# %%
pip install pandas
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ...
#   Using cached pytz-2025.2-py2.py3-none-any.whl (509 kB)
# ...
#   Using cached tzdata-2025.2-py2.py3-none-any.whl (347 kB)
# ...
# WARNING: You are using pip version 21.2.3; however, version 25.3 is available.
# You should consider upgrading via the 'c:\Users\Grace\Documents\Forecast Accuracy Publication Folder\.venv\Scripts\python.exe -m pip install --upgrade pip' command.

# %%
import pandas as pd

# %%
data= pd.read_csv('C:/Users/Grace/Documents/Forecast Accuracy Publication Folder/api/test data.csv')
data
# Out:
#      product_name      period Actual Consumption Forecast    Adopted Method
# 0            COCs  01/07/2020            132,830  114,101       Demographic
# 1            COCs  01/08/2020            130,332  114,101       Demographic
# 2            COCs  01/09/2020            132,812  114,101       Demographic
# 3            COCs  01/10/2020            135,550  114,101       Demographic
# 4            COCs  01/11/2020            130,697  114,101       Demographic
# ..            ...         ...                ...      ...               ...
# 840  Male Condoms  01/07/2025            1322091  3253078  Consumption LMIS
# 841  Male Condoms  01/08/2025            1333878  3253078  Consumption LMIS
# 842  Male Condoms  01/09/2025            1362762  3253078  Consumption LMIS
# 843  Male Condoms  01/10/2025                NaN  3253078  Consumption LMIS
# 844  Male Condoms  01/11/2025                NaN  3253078  Consumption LMIS
#
# [845 rows x 5 columns]
